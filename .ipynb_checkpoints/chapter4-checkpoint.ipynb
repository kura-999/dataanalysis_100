# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import pandas as pd
import numpy as np
import seaborn as sns
from math import radians, sin, cos, asin, sqrt

# %%
root_path = os.path.join(os.getcwd(), '100knock-data_analytics', '3章')

# %%
uselog_path = os.path.join(root_path, 'use_log.csv')
uselog = pd.read_csv(uselog_path)
uselog.isnull().sum()
# Out:
# log_id         0
# customer_id    0
# usedate        0
# dtype: int64

# %%
customer = pd.read_csv('customer_join.csv')
customer.isnull().sum()
# Out:
# customer_id             0
# name                    0
# class                   0
# gender                  0
# start_date              0
# end_date             2842
# campaign_id             0
# is_deleted              0
# class_name              0
# price                   0
# campaign_name           0
# mean                    0
# median                  0
# max                     0
# min                     0
# count                   0
# routine_flg             0
# calc_date               0
# membership_period       0
# dtype: int64

# %%
customer_clustering = customer[['mean', 'median', 'max', 'min', 'membership_period']]
customer_clustering
# Out:
#            mean  median  max  min  membership_period
# 0      4.833333     5.0    8    2                 47
# 1      5.083333     5.0    7    3                 47
# 2      4.583333     5.0    6    3                 47
# 3      4.833333     4.5    7    2                 47
# 4      3.916667     4.0    6    1                 47
# ...         ...     ...  ...  ...                ...
# 4187   8.000000     8.0    8    8                  1
# 4188  10.000000    10.0   10   10                  1
# 4189   8.000000     8.0    8    8                  1
# 4190  11.000000    11.0   11   11                  1
# 4191  10.000000    10.0   10   10                  1
#
# [4192 rows x 5 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
customer_clustering_sc = sc.fit_transform(customer_clustering)

kmeans = KMeans(n_clusters=4, random_state=0)
clusters = kmeans.fit(customer_clustering_sc)
customer_clustering = customer_clustering.assign(cluster = clusters.labels_)
label_mapping = {0: 3, 1: 2, 2: 1, 3: 0}
customer_clustering['cluster'] = customer_clustering['cluster'].map(label_mapping)

print(customer_clustering['cluster'].unique())
customer_clustering
# Out:
# [1 2 3 0]
#            mean  median  max  min  membership_period  cluster
# 0      4.833333     5.0    8    2                 47        1
# 1      5.083333     5.0    7    3                 47        1
# 2      4.583333     5.0    6    3                 47        1
# 3      4.833333     4.5    7    2                 47        1
# 4      3.916667     4.0    6    1                 47        1
# ...         ...     ...  ...  ...                ...      ...
# 4187   8.000000     8.0    8    8                  1        0
# 4188  10.000000    10.0   10   10                  1        0
# 4189   8.000000     8.0    8    8                  1        0
# 4190  11.000000    11.0   11   11                  1        0
# 4191  10.000000    10.0   10   10                  1        0
#
# [4192 rows x 6 columns]

# %%
customer_clustering.columns = ['月内平均値', '月内中央値', '月内最大値', '月内最小値', '会員期間', 'cluster']
customer_clustering.groupby('cluster').count()
# Out:
#          月内平均値  月内中央値  月内最大値  月内最小値  会員期間
# cluster
# 0          838    838    838    838   838
# 1         1249   1249   1249   1249  1249
# 2          771    771    771    771   771
# 3         1334   1334   1334   1334  1334

# %%
customer_clustering.groupby('cluster').mean()
# Out:
#             月内平均値     月内中央値      月内最大値     月内最小値       会員期間
# cluster
# 0        8.064079  8.050716  10.014320  6.180191   7.016706
# 1        4.677561  4.670937   7.233787  2.153723  36.915933
# 2        3.065504  2.900130   4.783398  1.649805   9.276265
# 3        5.541974  5.392804   8.757871  2.704648  14.857571

# %%
from sklearn.decomposition import PCA
X = customer_clustering_sc
pca = PCA(n_components=2)
pca.fit(X)
x_pca = pca.transform(X)
pca_df = pd.DataFrame(x_pca)
pca_df['cluster'] = customer_clustering['cluster']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for i in customer_clustering['cluster'].unique():
    tmp = pca_df.loc[pca_df['cluster']==i]
    plt.scatter(tmp[0], tmp[1])

# %%
pca_df
# Out:
#              0         1  cluster
# 0    -0.819982 -1.959097        1
# 1    -0.707922 -1.799857        1
# 2    -1.061499 -1.659826        1
# 3    -1.160764 -1.810139        1
# 4    -2.017132 -1.670101        1
# ...        ...       ...      ...
# 4187  3.027933  1.139635        0
# 4188  5.064720  0.769684        0
# 4189  3.027933  1.139635        0
# 4190  6.083114  0.584708        0
# 4191  5.064720  0.769684        0
#
# [4192 rows x 3 columns]

# %%
customer_clustering
# Out:
#           月内平均値  月内中央値  月内最大値  月内最小値  会員期間  cluster
# 0      4.833333    5.0      8      2    47        1
# 1      5.083333    5.0      7      3    47        1
# 2      4.583333    5.0      6      3    47        1
# 3      4.833333    4.5      7      2    47        1
# 4      3.916667    4.0      6      1    47        1
# ...         ...    ...    ...    ...   ...      ...
# 4187   8.000000    8.0      8      8     1        0
# 4188  10.000000   10.0     10     10     1        0
# 4189   8.000000    8.0      8      8     1        0
# 4190  11.000000   11.0     11     11     1        0
# 4191  10.000000   10.0     10     10     1        0
#
# [4192 rows x 6 columns]

# %%
customer
# Out:
#      customer_id   name class gender  start_date end_date campaign_id  \
# 0       OA832399   XXXX   C01      F  2015-05-01      NaN         CA1
# 1       PL270116  XXXXX   C01      M  2015-05-01      NaN         CA1
# 2       OA974876  XXXXX   C01      M  2015-05-01      NaN         CA1
# 3       HD024127  XXXXX   C01      F  2015-05-01      NaN         CA1
# 4       HD661448  XXXXX   C03      F  2015-05-01      NaN         CA1
# ...          ...    ...   ...    ...         ...      ...         ...
# 4187    HD676663   XXXX   C01      M  2019-03-14      NaN         CA1
# 4188    HD246549  XXXXX   C01      F  2019-03-14      NaN         CA1
# 4189    GD037007  XXXXX   C03      M  2019-03-14      NaN         CA1
# 4190    OA953150  XXXXX   C01      M  2019-03-14      NaN         CA1
# 4191    IK692635  XXXXX   C02      F  2019-03-15      NaN         CA1
#
#       is_deleted class_name  price campaign_name       mean  median  max  min  \
# 0              0     オールタイム  10500            通常   4.833333     5.0    8    2
# 1              0     オールタイム  10500            通常   5.083333     5.0    7    3
# 2              0     オールタイム  10500            通常   4.583333     5.0    6    3
# 3              0     オールタイム  10500            通常   4.833333     4.5    7    2
# 4              0        ナイト   6000            通常   3.916667     4.0    6    1
# ...          ...        ...    ...           ...        ...     ...  ...  ...
# 4187           0     オールタイム  10500            通常   8.000000     8.0    8    8
# 4188           0     オールタイム  10500            通常  10.000000    10.0   10   10
# 4189           0        ナイト   6000            通常   8.000000     8.0    8    8
# 4190           0     オールタイム  10500            通常  11.000000    11.0   11   11
# 4191           0      デイタイム   7500            通常  10.000000    10.0   10   10
#
#       count  routine_flg   calc_date  membership_period
# 0         4            1  2019-04-30                 47
# 1         5            1  2019-04-30                 47
# 2         5            1  2019-04-30                 47
# 3         5            1  2019-04-30                 47
# 4         5            1  2019-04-30                 47
# ...     ...          ...         ...                ...
# 4187      3            0  2019-04-30                  1
# 4188      3            0  2019-04-30                  1
# 4189      2            0  2019-04-30                  1
# 4190      3            0  2019-04-30                  1
# 4191      2            0  2019-04-30                  1
#
# [4192 rows x 19 columns]

# %%
customer_clustering = pd.concat([customer_clustering, customer], axis=1)
customer_clustering
# Out:
#           月内平均値  月内中央値  月内最大値  月内最小値  会員期間  cluster customer_id   name class  \
# 0      4.833333    5.0      8      2    47        1    OA832399   XXXX   C01
# 1      5.083333    5.0      7      3    47        1    PL270116  XXXXX   C01
# 2      4.583333    5.0      6      3    47        1    OA974876  XXXXX   C01
# 3      4.833333    4.5      7      2    47        1    HD024127  XXXXX   C01
# 4      3.916667    4.0      6      1    47        1    HD661448  XXXXX   C03
# ...         ...    ...    ...    ...   ...      ...         ...    ...   ...
# 4187   8.000000    8.0      8      8     1        0    HD676663   XXXX   C01
# 4188  10.000000   10.0     10     10     1        0    HD246549  XXXXX   C01
# 4189   8.000000    8.0      8      8     1        0    GD037007  XXXXX   C03
# 4190  11.000000   11.0     11     11     1        0    OA953150  XXXXX   C01
# 4191  10.000000   10.0     10     10     1        0    IK692635  XXXXX   C02
#
#      gender  ...  price campaign_name       mean  median max  min count  \
# 0         F  ...  10500            通常   4.833333     5.0   8    2     4
# 1         M  ...  10500            通常   5.083333     5.0   7    3     5
# 2         M  ...  10500            通常   4.583333     5.0   6    3     5
# 3         F  ...  10500            通常   4.833333     4.5   7    2     5
# 4         F  ...   6000            通常   3.916667     4.0   6    1     5
# ...     ...  ...    ...           ...        ...     ...  ..  ...   ...
# 4187      M  ...  10500            通常   8.000000     8.0   8    8     3
# 4188      F  ...  10500            通常  10.000000    10.0  10   10     3
# 4189      M  ...   6000            通常   8.000000     8.0   8    8     2
# 4190      M  ...  10500            通常  11.000000    11.0  11   11     3
# 4191      F  ...   7500            通常  10.000000    10.0  10   10     2
#
#       routine_flg   calc_date  membership_period
# 0               1  2019-04-30                 47
# 1               1  2019-04-30                 47
# 2               1  2019-04-30                 47
# 3               1  2019-04-30                 47
# 4               1  2019-04-30                 47
# ...           ...         ...                ...
# 4187            0  2019-04-30                  1
# 4188            0  2019-04-30                  1
# 4189            0  2019-04-30                  1
# 4190            0  2019-04-30                  1
# 4191            0  2019-04-30                  1
#
# [4192 rows x 25 columns]

# %%
customer_clustering.groupby(['cluster', 'is_deleted'], as_index=False).count()[['cluster', 'is_deleted', 'customer_id']]
# Out:
#    cluster  is_deleted  customer_id
# 0        0           0          820
# 1        0           1           18
# 2        1           0         1231
# 3        1           1           18
# 4        2           1          771
# 5        3           0          791
# 6        3           1          543

# %%
customer_clustering.groupby(['cluster', 'routine_flg'], as_index=False).count()[['cluster', 'routine_flg', 'customer_id']]
# Out:
#    cluster  routine_flg  customer_id
# 0        0            0           51
# 1        0            1          787
# 2        1            0            2
# 3        1            1         1247
# 4        2            0          499
# 5        2            1          272
# 6        3            0          227
# 7        3            1         1107

# %%
uselog
# Out:
#                  log_id customer_id     usedate
# 0       L00000049012330    AS009373  2018-04-01
# 1       L00000049012331    AS015315  2018-04-01
# 2       L00000049012332    AS040841  2018-04-01
# 3       L00000049012333    AS046594  2018-04-01
# 4       L00000049012334    AS073285  2018-04-01
# ...                 ...         ...         ...
# 197423  L00000049209753    TS977703  2019-03-31
# 197424  L00000049209754    TS979550  2019-03-31
# 197425  L00000049209755    TS995299  2019-03-31
# 197426  L00000049209756    TS995853  2019-03-31
# 197427  L00000049209757    TS999079  2019-03-31
#
# [197428 rows x 3 columns]

# %%
uselog['usedate'] = pd.to_datetime(uselog['usedate'])
uselog['年月'] = uselog['usedate'].dt.strftime('%Y%m')
uselog_months = uselog.groupby(['年月', 'customer_id'], as_index=False).count()
uselog_months.rename(columns={'log_id': 'count'}, inplace=True)
del uselog_months['usedate']
uselog_months
# Out:
#            年月 customer_id  count
# 0      201804    AS002855      4
# 1      201804    AS009013      2
# 2      201804    AS009373      3
# 3      201804    AS015315      6
# 4      201804    AS015739      7
# ...       ...         ...    ...
# 36837  201903    TS995853      8
# 36838  201903    TS998593      8
# 36839  201903    TS999079      3
# 36840  201903    TS999231      6
# 36841  201903    TS999855      4
#
# [36842 rows x 3 columns]

# %%
year_months = list(uselog_months['年月'].unique())
year_months
# Out:
# ['201804',
#  '201805',
#  '201806',
#  '201807',
#  '201808',
#  '201809',
#  '201810',
#  '201811',
#  '201812',
#  '201901',
#  '201902',
#  '201903']

# %%
predict_data = pd.DataFrame()
for i in range(6, len(year_months)):
    tmp = uselog_months.loc[uselog_months['年月']==year_months[i]].copy()
    tmp.rename(columns={'count': 'count_pred'}, inplace=True)
    for j in range(1, 7):
        tmp_before = uselog_months.loc[uselog_months['年月']==year_months[i-j]].copy()
        del tmp_before['年月']
        tmp_before.rename(columns={'count': 'count_{}'.format(j-1)}, inplace=True)
        tmp = pd.merge(tmp, tmp_before, on='customer_id', how='left')
    predict_data = pd.concat([predict_data, tmp], ignore_index=True)
predict_data
# Out:
#            年月 customer_id  count_pred  count_0  count_1  count_2  count_3  \
# 0      201810    AS002855           3      7.0      3.0      5.0      5.0
# 1      201810    AS008805           2      2.0      5.0      7.0      8.0
# 2      201810    AS009373           5      6.0      6.0      7.0      4.0
# 3      201810    AS015233           7      9.0     11.0      5.0      7.0
# 4      201810    AS015315           4      7.0      3.0      6.0      3.0
# ...       ...         ...         ...      ...      ...      ...      ...
# 18305  201903    TS995853           8     11.0      NaN      NaN      NaN
# 18306  201903    TS998593           8      7.0      8.0      7.0      9.0
# 18307  201903    TS999079           3      2.0      6.0      9.0      6.0
# 18308  201903    TS999231           6      6.0      3.0      8.0      5.0
# 18309  201903    TS999855           4      4.0      7.0      5.0      4.0
#
#        count_4  count_5
# 0          5.0      4.0
# 1          NaN      NaN
# 2          4.0      3.0
# 3          7.0      NaN
# 4          3.0      6.0
# ...        ...      ...
# 18305      NaN      NaN
# 18306      9.0      9.0
# 18307      6.0      4.0
# 18308      5.0      4.0
# 18309      4.0      5.0
#
# [18310 rows x 9 columns]

# %%
predict_data = predict_data.dropna()
predict_data = predict_data.reset_index(drop=True)
predict_data
# Out:
#            年月 customer_id  count_pred  count_0  count_1  count_2  count_3  \
# 0      201810    AS002855           3      7.0      3.0      5.0      5.0
# 1      201810    AS009373           5      6.0      6.0      7.0      4.0
# 2      201810    AS015315           4      7.0      3.0      6.0      3.0
# 3      201810    AS015739           5      6.0      5.0      8.0      6.0
# 4      201810    AS019860           7      5.0      7.0      4.0      6.0
# ...       ...         ...         ...      ...      ...      ...      ...
# 15108  201903    TS995299           3      3.0      5.0      4.0      5.0
# 15109  201903    TS998593           8      7.0      8.0      7.0      9.0
# 15110  201903    TS999079           3      2.0      6.0      9.0      6.0
# 15111  201903    TS999231           6      6.0      3.0      8.0      5.0
# 15112  201903    TS999855           4      4.0      7.0      5.0      4.0
#
#        count_4  count_5
# 0          5.0      4.0
# 1          4.0      3.0
# 2          3.0      6.0
# 3          5.0      7.0
# 4          8.0      6.0
# ...        ...      ...
# 15108      4.0      5.0
# 15109      9.0      9.0
# 15110      6.0      4.0
# 15111      5.0      4.0
# 15112      4.0      5.0
#
# [15113 rows x 9 columns]

# %%
predict_data = pd.merge(predict_data, customer[['customer_id', 'start_date']], on='customer_id', how='left')
predict_data
# Out:
#            年月 customer_id  count_pred  count_0  count_1  count_2  count_3  \
# 0      201810    AS002855           3      7.0      3.0      5.0      5.0
# 1      201810    AS009373           5      6.0      6.0      7.0      4.0
# 2      201810    AS015315           4      7.0      3.0      6.0      3.0
# 3      201810    AS015739           5      6.0      5.0      8.0      6.0
# 4      201810    AS019860           7      5.0      7.0      4.0      6.0
# ...       ...         ...         ...      ...      ...      ...      ...
# 15108  201903    TS995299           3      3.0      5.0      4.0      5.0
# 15109  201903    TS998593           8      7.0      8.0      7.0      9.0
# 15110  201903    TS999079           3      2.0      6.0      9.0      6.0
# 15111  201903    TS999231           6      6.0      3.0      8.0      5.0
# 15112  201903    TS999855           4      4.0      7.0      5.0      4.0
#
#        count_4  count_5  start_date
# 0          5.0      4.0  2016-11-01
# 1          4.0      3.0  2015-11-01
# 2          3.0      6.0  2015-07-01
# 3          5.0      7.0  2017-06-01
# 4          8.0      6.0  2017-10-01
# ...        ...      ...         ...
# 15108      4.0      5.0  2015-09-01
# 15109      9.0      9.0  2018-09-01
# 15110      6.0      4.0  2016-06-01
# 15111      5.0      4.0  2017-03-01
# 15112      4.0      5.0  2017-04-01
#
# [15113 rows x 10 columns]

# %%
predict_data['now_date'] = pd.to_datetime(predict_data['年月'], format='%Y%m')
predict_data['start_date'] = pd.to_datetime(predict_data['start_date'])

from dateutil.relativedelta import relativedelta

predict_data['period'] = None
for i in range(len(predict_data)):
    delta = relativedelta(predict_data.loc[i, 'now_date'], predict_data.loc[i, 'start_date'])
    predict_data.loc[i, 'period'] = delta.years*12 + delta.months
predict_data
# Out:
#            年月 customer_id  count_pred  count_0  count_1  count_2  count_3  \
# 0      201810    AS002855           3      7.0      3.0      5.0      5.0
# 1      201810    AS009373           5      6.0      6.0      7.0      4.0
# 2      201810    AS015315           4      7.0      3.0      6.0      3.0
# 3      201810    AS015739           5      6.0      5.0      8.0      6.0
# 4      201810    AS019860           7      5.0      7.0      4.0      6.0
# ...       ...         ...         ...      ...      ...      ...      ...
# 15108  201903    TS995299           3      3.0      5.0      4.0      5.0
# 15109  201903    TS998593           8      7.0      8.0      7.0      9.0
# 15110  201903    TS999079           3      2.0      6.0      9.0      6.0
# 15111  201903    TS999231           6      6.0      3.0      8.0      5.0
# 15112  201903    TS999855           4      4.0      7.0      5.0      4.0
#
#        count_4  count_5 start_date   now_date period
# 0          5.0      4.0 2016-11-01 2018-10-01     23
# 1          4.0      3.0 2015-11-01 2018-10-01     35
# 2          3.0      6.0 2015-07-01 2018-10-01     39
# 3          5.0      7.0 2017-06-01 2018-10-01     16
# 4          8.0      6.0 2017-10-01 2018-10-01     12
# ...        ...      ...        ...        ...    ...
# 15108      4.0      5.0 2015-09-01 2019-03-01     42
# 15109      9.0      9.0 2018-09-01 2019-03-01      6
# 15110      6.0      4.0 2016-06-01 2019-03-01     33
# 15111      5.0      4.0 2017-03-01 2019-03-01     24
# 15112      4.0      5.0 2017-04-01 2019-03-01     23
#
# [15113 rows x 12 columns]

# %%
predict_data = predict_data.loc[predict_data['start_date']>=pd.to_datetime('20180401')]

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

model = LinearRegression()
X = predict_data[['count_0', 'count_1', 'count_2', 'count_3', 'count_4', 'count_5', 'period']]
y = predict_data['count_pred']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.score(X_train, y_train))
print(model.score(X_test, y_test))
# Out:
# 0.6111525903215709
# 0.5964633323568844

# %%
coef = pd.DataFrame({'feature_names': X.columns, 'coefficient': model.coef_})
coef
# Out:
#   feature_names  coefficient
# 0       count_0     0.359133
# 1       count_1     0.181937
# 2       count_2     0.151177
# 3       count_3     0.184593
# 4       count_4     0.076946
# 5       count_5     0.058731
# 6        period     0.047007

# %%
x1 = [3, 4, 4, 6, 8, 7, 8]
x2 = [2, 2, 3, 3, 4, 6, 8]
x_pred = pd.DataFrame(data=[x1, x2], columns=['count_0', 'count_1', 'count_2', 'count_3', 'count_4', 'count_5', 'period'])
model.predict(x_pred)
# Out:
# array([3.77011036, 1.97563148])

# %%
uselog_months.to_csv('use_log_months.csv', index=False)
